// %%
clear all
cd "/Users/Charlie/Dropbox/Bankers in the Ivory Tower Book/2 Our New Financial Oligarchy/Data/Boards 2000 to 2017"

use board_members_all_long20181221, clear
keep if year==2017 & control!=.
set scheme plotplain
// Out:
// /Users/Charlie/Dropbox/Bankers in the Ivory Tower Book/2 Our New Financial Oligarchy/Data/Boards 2000 to 2017
//
//
// (32,888 observations deleted)

// %%
statplot hedgepealum otherfinalum nonfinalum, over(control, label(labsize(vsmall))) title("") blabel(bar, format(%9.1f)) ///
 name(alumnitrustees, replace) ytitle("% trustee type who are alumni") yscale(range(50 90)) ylabel(0(10)90) scheme(plotplain)

// %%
graph display
// Out:
// This front-end cannot display the desired image type.

// %%
graph export F5_board_alumni20200208.pdf, replace
// Out:
// (file F5_board_alumni20200208.pdf written in PDF format)
