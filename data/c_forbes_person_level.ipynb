// %% [markdown]
// ## Make Person-level Forbes 400 Alumni Data
//
// ### For Table 2 and Figures 1 through 3 of Elite Embeddedness
//
// By Charlie Eaton and Albina Gibadullina

// %%
import excel using "d_Forbes_400_education_hand_code.xlsx", clear firstrow
qui {
sort firstname lastname
foreach var in origin origindetail industry financedetail gender ///
college mba jd md otherprofdegree masters phd otherdegree1 otherdegree2 otherdegree3 otherdegree4 ///
name name1  name2 {
by firstname lastname: egen mode`var'=mode(`var')
replace `var'=mode`var' if `var'==""
}

destring boardunitid2 boardunitidotheryear boardunitidotheryear1, replace force
replace boardunitidotheryear=190415 if name=="190415"
replace name="cornell" if name=="190415"
replace boardunitid1=boardunitid2 if name1=="columbia" & name=="swarthmore"

foreach var in boardunitid1 boardunitid2 boardunitidotheryear boardunitidotheryear1 boardunitidotheryear2 alumni {
by firstname lastname: egen mode`var'=mode(`var')
replace `var'=mode`var' if `var'==.
}
drop mode*
}
// Out:
// (66 vars, 1,599 obs)

// %%
qui {
    drop if year==1982

replace financedetail="private equity" if lastname=="icahn" | lastname=="perelman"

replace financedetail="asset management" if firstname=="malcolm" & lastname=="chace" & year==2003 & financedetail==""
replace financedetail="asset management" if firstname=="warren" & lastname=="buffett" & year==2003 & financedetail==""
replace financedetail="asset management" if firstname=="susan" & lastname=="buffett" & year==2003 & financedetail==""
replace financedetail="asset management" if firstname=="thomas" & lastname=="marsico" & year==2003 & financedetail==""
replace financedetail="asset management" if firstname=="warren" & lastname=="buffett" & year==1989 & financedetail==""
replace financedetail="commercial banking" if firstname=="alfred" & lastname=="lerner" & year==1989 & financedetail==""
replace financedetail="commercial banking" if firstname=="alpheus" & lastname=="ellis" & year==1989 & financedetail==""
replace financedetail="commerical banking" if firstname=="bernard" & lastname=="osher" & year==2003 & financedetail==""
replace financedetail="commerical banking" if firstname=="jesse" & lastname=="robinson" & year==1989 & financedetail==""
replace financedetail="commerical banking" if firstname=="jesse" & lastname=="robinson" & year==2003 & financedetail==""
replace financedetail="commerical banking" if firstname=="carl" & lastname=="pohlad" & year==2003 & financedetail==""
replace financedetail="commerical banking" if firstname=="herbert" & lastname=="sandler" & year==2003 & financedetail==""
replace financedetail="commerical banking" if firstname=="marion" & lastname=="sandler" & year==2003 & financedetail==""
replace financedetail="hedge funds" if firstname=="steven" & lastname=="cohen" & year==2003 & financedetail==""
replace financedetail="insurance" if firstname=="leonard" & lastname=="abramson" & year==2003 & financedetail==""
replace financedetail="insurance" if firstname=="ernest" & lastname=="stempel" & year==2003 & financedetail==""
replace financedetail="insurance" if firstname=="maurice" & lastname=="greenberg" & year==1989 & financedetail==""
replace financedetail="insurance" if firstname=="maurice" & lastname=="greenberg" & year==2003 & financedetail==""
replace financedetail="insurance" if firstname=="robert" & lastname=="moody" & year==1989 & financedetail==""
replace financedetail="investment banking" if firstname=="robert" & lastname=="vankampen" & year==1989 & financedetail==""
replace financedetail="investment banking" if firstname=="sanford" & lastname=="weill" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="maggie" & lastname=="magerko" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="david" & lastname=="gold" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="samuel" & lastname=="frankino" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="andel" & lastname=="van" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="jeffrey" & lastname=="bezos" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="leonard" & lastname=="skaggs" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="stephen" & lastname=="case" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="joseph" & lastname=="neubauer" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="jack" & lastname=="tramiel" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="lynne" & lastname=="pasculano" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="james" & lastname=="france" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="france" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="james" & lastname=="moran" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="h" & lastname=="warner" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="anderson" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="anderson" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="dean" & lastname=="white" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="levine" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="robert" & lastname=="johnson" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="amar" & lastname=="bose" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="harold" & lastname=="honickman" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="marvin" & lastname=="herb" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="todd" & lastname=="wagner" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="august" & lastname=="meyer" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="orvon" & lastname=="autry" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="richard" & lastname=="wendt" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="joseph" & lastname=="hardy" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="alan" & lastname=="gerry" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="harold" & lastname=="lenfest" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="bob" & lastname=="magness" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="leonard" & lastname=="tow" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="stuart" & lastname=="levine" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="bobby" & lastname=="johnson" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="morgridge" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="jacqueline" & lastname=="vogel" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="billy" & lastname=="mccombs" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="thomas" & lastname=="friedkin" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="stephen" & lastname=="wynn" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="cook" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="fickling" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="jon" & lastname=="huntsman" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="donald" & lastname=="tyson" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="franklin" & lastname=="perdue" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="richard" & lastname=="farmer" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="bennett" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="pennington" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="l" & lastname=="mays" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="elizabeth" & lastname=="corn" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="turner" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="elizabeth" & lastname=="davenport" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="timothy" & lastname=="boyle" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="brian" & lastname=="roberts" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="kenneth" & lastname=="pontikes" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="malcolm" & lastname=="glazer" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="alfred" & lastname=="clark" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="harbert" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="henry" & lastname=="zachry" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="estee" & lastname=="lauder" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="nancy" & lastname=="dedman" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="robert" & lastname=="dedman" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="kenneth" & lastname=="behring" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="michael" & lastname=="eisner" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="victor" & lastname=="fung" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="ml" & lastname=="dupont greenwalt" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="anthony" & lastname=="pilaro" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="charles" & lastname=="feeney" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="richard" & lastname=="egan" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="jack" & lastname=="taylor" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="bruce" & lastname=="gottwald" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="floyd" & lastname=="gottwald" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="connor" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="leon" & lastname=="levine" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="albert" & lastname=="ueltschi" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="albert" & lastname=="ueltschi" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="luigino" & lastname=="paulucci" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="berkley" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="marvin" & lastname=="schwan" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="mark" & lastname=="goodson" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="donald" & lastname=="fisher" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="norman" & lastname=="waitt" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="theodore" & lastname=="waitt" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="davidson" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="charles" & lastname=="butt" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="davidson" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="allen" & lastname=="paulson" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="barbara" & lastname=="marshall" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="elizabeth" & lastname=="reid" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="pulte" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="roy" & lastname=="speer" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="richard" & lastname=="marriott" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="louis" & lastname=="gerstner" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="alice" & lastname=="dupont mills" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="alice" & lastname=="marriott" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="anne" & lastname=="gettyearhart" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="cargill" & lastname=="macmillan" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="caroline" & lastname=="getty" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="caroline" & lastname=="hunt" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="charlotte" & lastname=="weber" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="claire" & lastname=="gettyperry" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="constance" & lastname=="dupont darden" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="david" & lastname=="mugar" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="dorrance" & lastname=="hamilton" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="edith" & lastname=="dupont pearson" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="eleanor" & lastname=="dupont rust" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="elizabeth" & lastname=="reid" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="eugene" & lastname=="getty" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="frederick" & lastname=="koch" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="irene" & lastname=="dupont may" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="irenee" & lastname=="dupont" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="joan" & lastname=="kroc" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="walton" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="josephine" & lastname=="ford" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="louis" & lastname=="thalheimer" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="lucile" & lastname=="dupont flint" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="lucille" & lastname=="carver" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="mariana" & lastname=="dupont silliman" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="mary" & lastname=="dorrancemalone" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="nan" & lastname=="mcevoy" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="norton" & lastname=="clapp" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="octavia" & lastname=="dupont bredin" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="richard" & lastname=="marriott" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="richard" & lastname=="o’neill" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="anne" & lastname=="marion" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="anne" & lastname=="marion" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="barbara" & lastname=="johnson" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="barbara" & lastname=="marshall" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="howard" & lastname=="hillman" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="lillian" & lastname=="goldman" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="marshall" & lastname=="v" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="millicent" & lastname=="baoudjakdji" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="richard" & lastname=="kaleiokusmart" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="tatnall" & lastname=="hillman" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="anne" & lastname=="earhart" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="austin" & lastname=="hearst" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="barbara" & lastname=="gage" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="barbara" & lastname=="johnson" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="beuren" & lastname=="van" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="cargill" & lastname=="macmillan" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="caroline" & lastname=="getty" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="charlotte" & lastname=="weber" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="claire" & lastname=="perry" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="dorrance" & lastname=="hamilton" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="gary" & lastname=="magness" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="george" & lastname=="strawbridge" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="joan" & lastname=="kroc" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="leona" & lastname=="helmsley" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="leonore" & lastname=="annenberg" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="marguerite" & lastname=="harbert" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="marilyn" & lastname=="nelson" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="nancy" & lastname=="beck" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="norma" & lastname=="lerner" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="randolph" & lastname=="lerner" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="sarah" & lastname=="butler" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="arthur" & lastname=="williams" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="mansfield" & lastname=="freeman" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="arthur" & lastname=="williams" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="george" & lastname=="joseph" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="peter" & lastname=="lewis" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="morean" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="sidney" & lastname=="kimmel" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="kelly" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="jay" & lastname=="baker" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="herma" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="kellogg" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="gary" & lastname=="comer" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="gary" & lastname=="comer" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="joseph" & lastname=="jamail" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="joseph" & lastname=="jamail" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="leslie" & lastname=="gonda" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="louis" & lastname=="gonda" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="edson" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="edgar" & lastname=="bronfman" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="guilford" & lastname=="glazer" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="edson" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="richard" & lastname=="duchossois" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="michael" & lastname=="heisley" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="ewing" & lastname=="kauffman" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="richard" & lastname=="manoogian" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="richard" & lastname=="manoogian" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="bruce" & lastname=="mccaw" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="craig" & lastname=="mccaw" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="mccaw" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="keith" & lastname=="mccaw" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="robert" & lastname=="mclane" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="james" & lastname=="sorenson" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="abele" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="peter" & lastname=="nicholas" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="james" & lastname=="sorenson" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="wallace" & lastname=="coulter" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="cook" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="jeffrey" & lastname=="katzenberg" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="gary" & lastname=="burrell" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="lloyd" & lastname=="cotsen" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="keith" & lastname=="murdoch" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="harry" & lastname=="hoiles" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="maryjane" & lastname=="hardie" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="morris" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="richard" & lastname=="haworth" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="robert" & lastname=="holding" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="claude" & lastname=="pennington" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="james" & lastname=="marshall" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="joseph" & lastname=="gruss" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="philip" & lastname=="anschutz" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="frederick" & lastname=="koch" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="lawrence" & lastname=="ellison" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="lawrence" & lastname=="ellison" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="mary" & lastname=="anselmo" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="mark" & lastname=="smith" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="thomas" & lastname=="monaghan" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="jon" & lastname=="huntsman" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="cleon" & lastname=="knapp" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="gertrude" & lastname=="crain" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="keith" & lastname=="murdoch" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="ralph" & lastname=="ingersoll" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="walter" & lastname=="annenberg" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="dwight" & lastname=="opperman" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="nan" & lastname=="mcevoy" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="irwin" & lastname=="jacobs" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="philip" & lastname=="anschutz" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="ollen" & lastname=="smith" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="alan" & lastname=="casden" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="alfred" & lastname=="goldman" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="arthur" & lastname=="cohen" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="carl" & lastname=="berg" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="david" & lastname=="chase" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="francesco" & lastname=="galesi" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="frank" & lastname=="morgan" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="frank" & lastname=="pasquerilla" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="fred" & lastname=="crow" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="guilford" & lastname=="glazer" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="harold" & lastname=="brown" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="hugh" & lastname=="culverhouse" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="ian" & lastname=="woodner" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="hammons" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="judd" & lastname=="malkin" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="kingdon" & lastname=="gould" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="laszlo" & lastname=="tauber" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="lawrence" & lastname=="fisher" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="leonard" & lastname=="litwin" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="m" & lastname=="lawrence" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="marvin" & lastname=="oates" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="miller" & lastname=="nichols" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="royal" & lastname=="durst" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="samuel" & lastname=="zell" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="samuel" & lastname=="zell" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="sherman" & lastname=="dreiseszun" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="stanley" & lastname=="stahl" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="theodore" & lastname=="lerner" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="thomas" & lastname=="flatley" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="thomas" & lastname=="flatley" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="lyon" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="paul" & lastname=="fireman" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="paul" & lastname=="fireman" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="michael" & lastname=="krasny" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="louis" & lastname=="ward" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="christopher" & lastname=="goldsbury" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="edgar" & lastname=="bronfman" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="edward" & lastname=="watkins" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="robert" & lastname=="congel" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="william" & lastname=="cafaro" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="jerry" & lastname=="moore" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="richard" & lastname=="jacobs" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="robert" & lastname=="congel" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="aubrey" & lastname=="chernick" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="moores" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="rangos" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="ronald" & lastname=="burkle" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="charles" & lastname=="butt" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="joyce" & lastname=="teel" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="patrick" & lastname=="taylor" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="bruce" & lastname=="mccaw" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="craig" & lastname=="mccaw" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="mccaw" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="kenny" & lastname=="troutt" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="aaron" & lastname=="spelling" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="andrew" & lastname=="perenchio" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="mervyn" & lastname=="griffin" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="andrew" & lastname=="perenchio" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="herbert" & lastname=="siegel" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="marcy" & lastname=="carsey" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="tom" & lastname=="werner" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="hollingsworth" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="gerrish" & lastname=="milliken" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="minot" & lastname=="milliken" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="donald" & lastname=="fisher" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="bella" & lastname=="wexner" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="marshall" & lastname=="naify" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="michael" & lastname=="forman" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="robert" & lastname=="naify" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="christel" & lastname=="dehaan" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="james" & lastname=="moran" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="johnnie" & lastname=="hunt" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="donald" & lastname=="schneider" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="robert" & lastname=="turner" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="edmund" & lastname=="ansin" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="barbara" & lastname=="tyson" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="donald" & lastname=="tyson" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="robert" & lastname=="naify" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="james" & lastname=="walton" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="robert" & lastname=="mclane" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="helen" & lastname=="walton" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="walton" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="jess" & lastname=="jackson" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="berry" & year==1989 & financedetail==""
replace financedetail="private equity" if firstname=="john" & lastname=="sperling" & year==2003 & financedetail==""
replace financedetail="private equity" if firstname=="peter" & lastname=="sperling" & year==2003 & financedetail==""
replace financedetail="private equity" if firstname=="jerome" & lastname=="kohlberg" & year==1989 & financedetail==""
replace financedetail="private equity" if firstname=="jerome" & lastname=="kohlberg" & year==2003 & financedetail==""
replace financedetail="private equity" if firstname=="nelson" & lastname=="peltz" & year==1989 & financedetail==""
replace financedetail="private equity" if firstname=="nelson" & lastname=="peltz" & year==2003 & financedetail==""
replace financedetail="private equity" if firstname=="theodore" & lastname=="forstmann" & year==2003 & financedetail==""
replace financedetail="private equity" if firstname=="thomas" & lastname=="hicks" & year==2003 & financedetail==""
replace financedetail="private equity" if firstname=="william" & lastname=="simon" & year==1989 & financedetail==""
replace financedetail="venture capital" if firstname=="arthur" & lastname=="rock" & year==2003 & financedetail==""
replace financedetail="venture capital" if firstname=="william" & lastname=="bowes" & year==2003 & financedetail==""
replace financedetail="investment banking" if firstname=="thomas" & lastname=="dittmer" & year==1989 & financedetail==""
replace financedetail="hedge funds" if firstname=="pincus" & lastname=="green" & year==1989 & financedetail==""
replace financedetail="hedge funds" if firstname=="pincus" & lastname=="green" & year==2003 & financedetail==""
replace financedetail="private equity" if firstname=="meshulam" & lastname=="riklis" & year==1989 & financedetail==""
replace financedetail="asset management" if firstname=="fayez" & lastname=="sarofim" & year==2003 & financedetail==""
replace financedetail="venture capital" if firstname=="betsey" & lastname=="rooseveltwhitney" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="e" & lastname=="marshall" & year==2003 & financedetail==""
replace financedetail="commercial banking" if firstname=="joshua" & lastname=="green" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="alfred" & lastname=="mann" & year==2003 & financedetail==""
replace financedetail="investment banking" if firstname=="jackson" & lastname=="stephens" & year==2003 & financedetail==""
replace financedetail="investment banking" if firstname=="jackson" & lastname=="stephens" & year==1989 & financedetail==""
replace financedetail="investment banking" if firstname=="shelby" & lastname=="davis" & year==1989 & financedetail==""
replace financedetail="investment banking" if firstname=="wilton" & lastname=="stephens" & year==1989 & financedetail==""
replace financedetail="private equity" if firstname=="harold" & lastname=="simmons" & year==1989 & financedetail==""
replace financedetail="asset management" if firstname=="richard" & lastname=="rainwater" & year==1989 & financedetail==""
replace financedetail="asset management" if firstname=="charles" & lastname=="munger" & year==2003 & financedetail==""
replace financedetail="hedge funds" if firstname=="edward" & lastname=="lampert" & year==2003 & financedetail==""
replace financedetail="asset management" if firstname=="franklin" & lastname=="booth" & year==2003 & financedetail==""
replace financedetail="private equity" if firstname=="harold" & lastname=="simmons" & year==2003 & financedetail==""
replace financedetail="hedge funds" if firstname=="jack" & lastname=="nash" & year==2003 & financedetail==""
replace financedetail="private equity" if firstname=="lowell" & lastname=="milken" & year==2003 & financedetail==""
replace financedetail="asset management" if firstname=="norman" & lastname=="hascoe" & year==2003 & financedetail==""
replace financedetail="asset management" if firstname=="richard" & lastname=="rainwater" & year==2003 & financedetail==""
replace financedetail="hedge funds" if firstname=="samuel" & lastname=="wyly" & year==2003 & financedetail==""
replace financedetail="asset management" if firstname=="thomas" & lastname=="bailey" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="daniel" & lastname=="terra" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="carl" & lastname=="pohlad" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="james" & lastname=="kim" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="steven" & lastname=="ballmer" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="frederick" & lastname=="krehbiel" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="krehbiel" & year==2003 & financedetail==""
replace financedetail="asset management" if firstname=="alberto" & lastname=="vilar" & year==2003 & financedetail==""
replace financedetail="asset management" if firstname=="alfred" & lastname=="west" & year==2003 & financedetail==""
replace financedetail="hedge funds" if firstname=="michael" & lastname=="price" & year==2003 & financedetail==""
replace financedetail="asset management" if firstname=="robert" & lastname=="day" & year==2003 & financedetail==""
replace financedetail="asset management" if firstname=="richard" & lastname=="strong" & year==2003 & financedetail==""
replace financedetail="asset management" if firstname=="fayez" & lastname=="sarofim" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="blase" & lastname=="golisano" & year==2003 & financedetail==""
replace financedetail="non-financial" if firstname=="fritz" & lastname=="haas" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="john" & lastname=="haas" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="norman" & lastname=="alexander" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="harry" & lastname=="lebensfeld" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="donald" & lastname=="graham" & year==1989 & financedetail==""
replace financedetail="non-financial" if firstname=="andrew" & lastname=="mckelvey" & year==2003 & financedetail==""

replace technology=1 if firstname=="jeffrey" & lastname=="bezos" & year==2003
replace technology=1 if firstname=="jack" & lastname=="tramiel" & year==1989
replace technology=1 if firstname=="john" & lastname=="morgridge" & year==2003
replace technology=1 if firstname=="kenneth" & lastname=="pontikes" & year==1989
replace technology=1 if firstname=="louis" & lastname=="gerstner" & year==2003
replace technology=1 if firstname=="bruce" & lastname=="mccaw" & year==1989
replace technology=1 if firstname=="craig" & lastname=="mccaw" & year==1989
replace technology=1 if firstname=="john" & lastname=="mccaw" & year==1989
replace technology=1 if firstname=="keith" & lastname=="mccaw" & year==1989
replace technology=1 if firstname=="gary" & lastname=="burrell" & year==2003
replace technology=1 if firstname=="lawrence" & lastname=="ellison" & year==1989
replace technology=1 if firstname=="lawrence" & lastname=="ellison" & year==2003
replace technology=1 if firstname=="mary" & lastname=="anselmo" & year==2003
replace technology=1 if firstname=="mark" & lastname=="smith" & year==2003
replace technology=1 if firstname=="irwin" & lastname=="jacobs" & year==2003
replace technology=1 if firstname=="philip" & lastname=="anschutz" & year==2003
replace technology=1 if firstname=="edward" & lastname=="watkins" & year==2003
replace technology=1 if firstname=="aubrey" & lastname=="chernick" & year==2003
replace technology=1 if firstname=="john" & lastname=="moores" & year==2003
replace technology=1 if firstname=="bruce" & lastname=="mccaw" & year==2003
replace technology=1 if firstname=="craig" & lastname=="mccaw" & year==2003
replace technology=1 if firstname=="john" & lastname=="mccaw" & year==2003
replace technology=1 if firstname=="kenny" & lastname=="troutt" & year==2003
replace technology=1 if firstname=="alfred" & lastname=="mann" & year==2003
replace technology=1 if firstname=="carl" & lastname=="pohlad" & year==1989
replace technology=1 if firstname=="james" & lastname=="kim" & year==2003
replace technology=1 if firstname=="steven" & lastname=="ballmer" & year==2003
replace technology=1 if firstname=="frederick" & lastname=="krehbiel" & year==2003
replace technology=1 if firstname=="john" & lastname=="krehbiel" & year==2003
replace technology=1 if industry=="technology" | industry=="electronics"

gen collegeunitid=.
  replace collegeunitid=166629 if regexm(college, "university of massachusetts amherst")==1
  replace collegeunitid=189097 if regexm(college, "barnard")==1
  replace collegeunitid=160977 if regexm(college, "bates")==1
  replace collegeunitid=164924 if regexm(college, "boston college")==1
  replace collegeunitid=161004 if regexm(college, "bowdoin")==1
  replace collegeunitid=165015 if regexm(college, "brandeis")==1
  replace collegeunitid=217156 if regexm(college, "brown")==1
  replace collegeunitid=211273 if regexm(college, "bryn mawr")==1
  replace collegeunitid=211291 if regexm(college, "bucknell")==1
  replace collegeunitid=110404 if regexm(college, "caltech")==1
  replace collegeunitid=173258 if regexm(college, "carleton")==1
  replace collegeunitid=112260 if regexm(college, "claremont mckenna")==1
  replace collegeunitid=161086 if regexm(college, "colby")==1
  replace collegeunitid=190099 if regexm(college, "colgate")==1
  replace collegeunitid=126818 if regexm(college, "colorado state")==1
  replace collegeunitid=190150 if regexm(college, "columbia")==1
  replace collegeunitid=190415 if regexm(college, "cornell")==1
  replace collegeunitid=182670 if regexm(college, "dartmouth")==1
  replace collegeunitid=198385 if regexm(college, "davidson")==1
  replace collegeunitid=198419 if regexm(college, "duke")==1
  replace collegeunitid=139658 if regexm(college, "emory")==1
  replace collegeunitid=131496 if regexm(college, "georgetown")==1
  replace collegeunitid=153384 if regexm(college, "grinnell")==1
  replace collegeunitid=191515 if regexm(college, "hamilton")==1
  replace collegeunitid=166027 if regexm(college, "harvard university")==1
  replace collegeunitid=212911 if regexm(college, "haverford")==1
  replace collegeunitid=162928 if regexm(college, "johns hopkins")==1
  replace collegeunitid=203535 if regexm(college, "kenyon")==1
  replace collegeunitid=173902 if regexm(college, "macalester")==1
  replace collegeunitid=230959 if regexm(college, "middlebury")==1
  replace collegeunitid=166683 if regexm(college, "massachusetts institute of technology")==1
  replace collegeunitid=166939 if regexm(college, "mount holyoke")==1
  replace collegeunitid=147767 if regexm(college, "northwestern")==1
  replace collegeunitid=193900 if regexm(college, "new york university")==1
  replace collegeunitid=204501 if regexm(college, "oberlin")==1
  replace collegeunitid=121345 if regexm(college, "pomona")==1
  replace collegeunitid=186131 if regexm(college, "princeton")==1
  replace collegeunitid=227757 if regexm(college, "rice")==1
  replace collegeunitid=167835 if regexm(college, "smith")==1
  replace collegeunitid=243744 if regexm(college, "stanford")==1
  replace collegeunitid=216287 if regexm(college, "swarthmore")==1
  replace collegeunitid=130590 if regexm(college, "trinity")==1
  replace collegeunitid=144050 if regexm(college, "university of chicago")==1
  replace collegeunitid=215062 if regexm(college, "university of pennsylvania")==1
  replace collegeunitid=221999 if regexm(college, "vanderbilt")==1
  replace collegeunitid=197133 if regexm(college, "vassar")==1
  replace collegeunitid=179867 if regexm(college, "washington university")==1
  replace collegeunitid=168218 if regexm(college, "wellesley")==1
  replace collegeunitid=130697 if regexm(college, "wesleyan")==1
  replace collegeunitid=168342 if regexm(college, "williams")==1
  replace collegeunitid=130794 if regexm(college, "yale")==1

**NEW collegeunitid CODING BY HYUNSU**
  replace collegeunitid=243780 if regexm(college, "purdue")==1
  replace collegeunitid=102614 if regexm(college, "alaska")==1
  replace collegeunitid=104179 if regexm(college, "arizona state")==1
  replace collegeunitid=164988 if regexm(college, "boston university")==1
  replace collegeunitid=110404 if regexm(college, "california institute of technology")==1
  replace collegeunitid=211440 if regexm(college, "carnegie mellon")==1
  replace collegeunitid=201645 if regexm(college, "case western reserve")==1
  replace collegeunitid=232186 if regexm(college, "george mason")==1
  replace collegeunitid=139959 if regexm(college, "georgia")==1
  replace collegeunitid=151351 if regexm(college, "indiana")==1  
  replace collegeunitid=163286 if regexm(college, "maryland")==1 
  replace collegeunitid=166683 if regexm(college, "massachusetts institute of technology")==1 
  replace collegeunitid=171100 if regexm(college, "michigan state")==1 
  replace collegeunitid=193900 if regexm(college, "new york")==1   
  replace collegeunitid=167358 if regexm(college, "northeastern")==1 
  replace collegeunitid=204796 if regexm(college, "ohio state")==1 
  replace collegeunitid=209542 if regexm(college, "oregon state")==1   
  replace collegeunitid=214777 if regexm(college, "pennsylvania state")==1 
  replace collegeunitid=186380 if regexm(college, "rutgers")==1 
  replace collegeunitid=228723 if regexm(college, "texas a&m")==1 
  replace collegeunitid=168148 if regexm(college, "tufts")==1 
  replace collegeunitid=110635 if regexm(college, "university of california")==1 
  replace collegeunitid=201885 if regexm(college, "university of cincinnati")==1   
  replace collegeunitid=129020 if regexm(college, "university of connecticut")==1 
  replace collegeunitid=141574 if regexm(college, "university of hawai")==1 
  replace collegeunitid=145637 if regexm(college, "university of illinois")==1 
  replace collegeunitid=170976 if regexm(college, "university of michigan")==1 
  replace collegeunitid=174066 if regexm(college, "university of minnesota")==1 
  replace collegeunitid=181464 if regexm(college, "university of nebraska-lincoln")==1   
  replace collegeunitid=199120 if regexm(college, "university of north carolina")==1 
  replace collegeunitid=152080 if regexm(college, "university of notre dame")==1   
  replace collegeunitid=195030 if regexm(college, "university of rochester")==1 
  replace collegeunitid=123961 if regexm(college, "university of southern california")==1 
  replace collegeunitid=221759 if regexm(college, "university of tennessee")==1 
  replace collegeunitid=228778 if regexm(college, "university of texas")==1 
  replace collegeunitid=234076 if regexm(college, "university of virginia")==1 
  replace collegeunitid=236948 if regexm(college, "university of washington")==1  
  replace collegeunitid=240444 if regexm(college, "university of wisconsin")==1  
  replace collegeunitid=126614 if regexm(college, "university of colorado")==1
  
    replace collegeunitid=164465 if regexm(college, "amherst")==1
  replace collegeunitid=189097 if regexm(college, "barnard")==1
  replace collegeunitid=160977 if regexm(college, "bates")==1
  replace collegeunitid=164924 if regexm(college, "boston college")==1
  replace collegeunitid=161004 if regexm(college, "bowdoin")==1
  replace collegeunitid=165015 if regexm(college, "brandeis")==1
  replace collegeunitid=217156 if regexm(college, "brown")==1
  replace collegeunitid=211273 if regexm(college, "bryn mawr")==1
  replace collegeunitid=211291 if regexm(college, "bucknell")==1
  replace collegeunitid=110404 if regexm(college, "caltech")==1
  replace collegeunitid=173258 if regexm(college, "carleton")==1
  replace collegeunitid=112260 if regexm(college, "claremont mckenna")==1
  replace collegeunitid=161086 if regexm(college, "colby")==1
  replace collegeunitid=190099 if regexm(college, "colgate")==1
  replace collegeunitid=126678 if regexm(college, "colorado")==1
  replace collegeunitid=190150 if regexm(college, "columbia")==1
  replace collegeunitid=190415 if regexm(college, "cornell")==1
  replace collegeunitid=182670 if regexm(college, "dartmouth")==1
  replace collegeunitid=198385 if regexm(college, "davidson")==1
  replace collegeunitid=198419 if regexm(college, "duke")==1
  replace collegeunitid=139658 if regexm(college, "emory")==1
  replace collegeunitid=131496 if regexm(college, "georgetown")==1
  replace collegeunitid=153384 if regexm(college, "grinnell")==1
  replace collegeunitid=191515 if regexm(college, "hamilton")==1
  replace collegeunitid=166027 if regexm(college, "harvard")==1
  replace collegeunitid=212911 if regexm(college, "haverford")==1
  replace collegeunitid=162928 if regexm(college, "johns hopkins")==1
  replace collegeunitid=203535 if regexm(college, "kenyon")==1
  replace collegeunitid=213385 if regexm(college, "lafayette")==1
  replace collegeunitid=173902 if regexm(college, "macalester")==1
  replace collegeunitid=230959 if regexm(college, "middlebury")==1
  replace collegeunitid=166683 if college=="mit"
  replace collegeunitid=166939 if regexm(college, "mount holyoke")==1
  replace collegeunitid=147767 if regexm(college, "northwestern")==1
  replace collegeunitid=193900 if regexm(college, "nyu")==1
  replace collegeunitid=204501 if regexm(college, "oberlin")==1
  replace collegeunitid=121345 if regexm(college, "pomona")==1
  replace collegeunitid=186131 if regexm(college, "princeton")==1
  replace collegeunitid=227757 if regexm(college, "rice")==1
  replace collegeunitid=167835 if regexm(college, "smith")==1
  replace collegeunitid=243744 if regexm(college, "stanford")==1
  replace collegeunitid=216287 if regexm(college, "swarthmore")==1
  replace collegeunitid=130590 if regexm(college, "trinity")==1
  replace collegeunitid=144050 if regexm(college, "university of chicago")==1
  replace collegeunitid=215062 if regexm(college, "university of pennsylvania")==1
  replace collegeunitid=221999 if regexm(college, "vanderbilt")==1
  replace collegeunitid=197133 if regexm(college, "vassar")==1
  replace collegeunitid=179867 if regexm(college, "washington university")==1
  replace collegeunitid=168218 if regexm(college, "wellesley")==1
  replace collegeunitid=130697 if regexm(college, "wesleyan")==1
  replace collegeunitid=168342 if regexm(college, "williams")==1
  replace collegeunitid=130794 if regexm(college, "yale")==1
replace collegeunitid=188429 if college=="adelphi university"
replace collegeunitid=197708 if college=="albert einstein college of medicine"
replace collegeunitid=131159 if college=="american university"
replace collegeunitid=100830 if college=="auburn university"
replace collegeunitid=100830 if college=="auburn university"
replace collegeunitid=164580 if college=="babson college"
replace collegeunitid=164580 if college=="babson college"
replace collegeunitid=190512 if college=="baruch college"
replace collegeunitid=223232 if college=="baylor university (jd)"
replace collegeunitid=238333 if college=="beloit college"
replace collegeunitid=196079 if college=="binghamton university"
replace collegeunitid=230038 if college=="brigham young university"
replace collegeunitid=190549 if college=="brooklyn college"
replace collegeunitid=110422 if college=="california state polytechnical university"
replace collegeunitid=110583 if college=="california state university, long beach"
replace collegeunitid=110592 if college=="california state university, los angeles"
replace collegeunitid=169080 if college=="calvin college"
replace collegeunitid=111948 if college=="chapman university"
replace collegeunitid=181002 if college=="creighton university"
replace collegeunitid=150400 if college=="depauw university"
replace collegeunitid=212009 if college=="dickinson college"
replace collegeunitid=177214 if college=="drury university"
replace collegeunitid=169798 if college=="eastern michigan university"
replace collegeunitid=433660 if college=="florida gulf coast university"
replace collegeunitid=115755 if college=="humboldt state university"
replace collegeunitid=190594 if college=="hunter college"
replace collegeunitid=151290 if college=="indian institute of technology"
replace collegeunitid=203368 if college=="john carroll university"
replace collegeunitid=170532 if college=="kalamazoo college"
replace collegeunitid=226231 if college=="letourneau university"
replace collegeunitid=192448 if college=="long island university"
replace collegeunitid=146719 if college=="loyola university"
replace collegeunitid=237525 if college=="marshall university"
replace collegeunitid=155511 if college=="mcpherson college"
replace collegeunitid=204006 if college=="miami university"
replace collegeunitid=220978 if college=="middle tennessee state university"
replace collegeunitid=174358 if college=="minnesota state university"
replace collegeunitid=199193 if college=="north carolina state university"
replace collegeunitid=147703 if college=="northern illinois university"
replace collegeunitid=171456 if college=="northern michigan university"
replace collegeunitid=204635 if college=="ohio northern university"
replace collegeunitid=121150 if college=="pepperdine university"
replace collegeunitid=233277 if college=="radford university"
replace collegeunitid=217493 if college=="rhode island school of design"
replace collegeunitid=163851 if college=="salisbury state university"
replace collegeunitid=122409 if college=="san diego state university"
replace collegeunitid=122755 if college=="san jose state university"
replace collegeunitid=122931 if college=="santa clara university"
replace collegeunitid=228246 if college=="southern methodist university"
replace collegeunitid=228343 if college=="southwestern university"
replace collegeunitid=174792 if college=="st. john's university"
replace collegeunitid=110662 if college=="ucla"
replace collegeunitid=196097 if college=="stony brook university"
replace collegeunitid=196413 if college=="syracuse university"
replace collegeunitid=216339 if college=="temple university"
replace collegeunitid=221838 if college=="tennessee state university"
replace collegeunitid=221847 if college=="tennessee technological university"
replace collegeunitid=229115 if college=="texas tech university"
replace collegeunitid=160755 if college=="tulane university"
replace collegeunitid=164155 if college=="united states naval academy"
replace collegeunitid=104179 if college=="university of arizona"
replace collegeunitid=106397 if college=="university of arkansas"
replace collegeunitid=161873 if college=="university of baltimore"
replace collegeunitid=106704 if college=="university of central arkansas"
replace collegeunitid=169716 if college=="university of detroit, mercy"
replace collegeunitid=135726 if college=="university of miami"
replace collegeunitid=178396 if college=="university of missouri"
replace collegeunitid=181215 if college=="university of nebraska"
replace collegeunitid=159939 if college=="university of new orleans"
replace collegeunitid=209551 if college=="university of oregon"
replace collegeunitid=215293 if college=="university of pittsburgh"
replace collegeunitid=120883 if college=="university of the pacific"
replace collegeunitid=230764 if college=="university of utah"
replace collegeunitid=110662 if college=="universtiy of california, los angeles"
replace collegeunitid=216597 if college=="villanova university"
replace collegeunitid=199847 if college=="wake forest university"
replace collegeunitid=236939 if college=="washington state university"
replace collegeunitid=172644 if college=="wayne state university law school"
replace collegeunitid=157951 if college=="western kentucky university"
replace collegeunitid=172699 if college=="western michigan university"
replace collegeunitid=156125 if college=="wichita state university"
replace collegeunitid=218973 if college=="wofford college"

gen mbaunitid=.
  replace mbaunitid=166629 if regexm(mba, "university of massachusetts amherst")==1
  replace mbaunitid=189097 if regexm(mba, "barnard")==1
  replace mbaunitid=160977 if regexm(mba, "bates")==1
  replace mbaunitid=164924 if regexm(mba, "boston college")==1
  replace mbaunitid=161004 if regexm(mba, "bowdoin")==1
  replace mbaunitid=165015 if regexm(mba, "brandeis")==1
  replace mbaunitid=217156 if regexm(mba, "brown")==1
  replace mbaunitid=211273 if regexm(mba, "bryn mawr")==1
  replace mbaunitid=211291 if regexm(mba, "bucknell")==1
  replace mbaunitid=110404 if regexm(mba, "caltech")==1
  replace mbaunitid=173258 if regexm(mba, "carleton")==1
  replace mbaunitid=112260 if regexm(mba, "claremont mckenna")==1
  replace mbaunitid=161086 if regexm(mba, "colby")==1
  replace mbaunitid=190099 if regexm(mba, "colgate")==1
  replace mbaunitid=126818 if regexm(mba, "colorado state")==1
  replace mbaunitid=190150 if regexm(mba, "columbia")==1
  replace mbaunitid=190415 if regexm(mba, "cornell")==1
  replace mbaunitid=182670 if regexm(mba, "dartmouth")==1
  replace mbaunitid=198385 if regexm(mba, "davidson")==1
  replace mbaunitid=198419 if regexm(mba, "duke")==1
  replace mbaunitid=139658 if regexm(mba, "emory")==1
  replace mbaunitid=131496 if regexm(mba, "georgetown")==1
  replace mbaunitid=153384 if regexm(mba, "grinnell")==1
  replace mbaunitid=191515 if regexm(mba, "hamilton")==1
  replace mbaunitid=166027 if regexm(mba, "harvard university")==1
  replace mbaunitid=212911 if regexm(mba, "haverford")==1
  replace mbaunitid=162928 if regexm(mba, "johns hopkins")==1
  replace mbaunitid=203535 if regexm(mba, "kenyon")==1
  replace mbaunitid=173902 if regexm(mba, "macalester")==1
  replace mbaunitid=230959 if regexm(mba, "middlebury")==1
  replace mbaunitid=166683 if regexm(mba, "massachusetts institute of technology")==1
  replace mbaunitid=166939 if regexm(mba, "mount holyoke")==1
  replace mbaunitid=147767 if regexm(mba, "northwestern")==1
  replace mbaunitid=193900 if regexm(mba, "new york university")==1
  replace mbaunitid=204501 if regexm(mba, "oberlin")==1
  replace mbaunitid=121345 if regexm(mba, "pomona")==1
  replace mbaunitid=186131 if regexm(mba, "princeton")==1
  replace mbaunitid=227757 if regexm(mba, "rice")==1
  replace mbaunitid=167835 if regexm(mba, "smith")==1
  replace mbaunitid=243744 if regexm(mba, "stanford")==1
  replace mbaunitid=216287 if regexm(mba, "swarthmore")==1
  replace mbaunitid=130590 if regexm(mba, "trinity")==1
  replace mbaunitid=144050 if regexm(mba, "university of chicago")==1
  replace mbaunitid=215062 if regexm(mba, "university of pennsylvania")==1
  replace mbaunitid=221999 if regexm(mba, "vanderbilt")==1
  replace mbaunitid=197133 if regexm(mba, "vassar")==1
  replace mbaunitid=179867 if regexm(mba, "washington university")==1
  replace mbaunitid=168218 if regexm(mba, "wellesley")==1
  replace mbaunitid=130697 if regexm(mba, "wesleyan")==1
  replace mbaunitid=168342 if regexm(mba, "williams")==1
  replace mbaunitid=130794 if regexm(mba, "yale")==1

**NEW mbaunitid CODING BY HYUNSU**
  replace mbaunitid=243780 if regexm(mba, "purdue")==1
  replace mbaunitid=102614 if regexm(mba, "alaska")==1
  replace mbaunitid=104179 if regexm(mba, "arizona state")==1
  replace mbaunitid=164988 if regexm(mba, "boston university")==1
  replace mbaunitid=110404 if regexm(mba, "california institute of technology")==1
  replace mbaunitid=211440 if regexm(mba, "carnegie mellon")==1
  replace mbaunitid=201645 if regexm(mba, "case western reserve")==1
  replace mbaunitid=232186 if regexm(mba, "george mason")==1
  replace mbaunitid=139959 if regexm(mba, "georgia")==1
  replace mbaunitid=151351 if regexm(mba, "indiana")==1  
  replace mbaunitid=163286 if regexm(mba, "maryland")==1 
  replace mbaunitid=166683 if regexm(mba, "massachusetts institute of technology")==1 
  replace mbaunitid=171100 if regexm(mba, "michigan state")==1 
  replace mbaunitid=193900 if regexm(mba, "new york")==1   
  replace mbaunitid=167358 if regexm(mba, "northeastern")==1 
  replace mbaunitid=204796 if regexm(mba, "ohio state")==1 
  replace mbaunitid=209542 if regexm(mba, "oregon state")==1   
  replace mbaunitid=214777 if regexm(mba, "pennsylvania state")==1 
  replace mbaunitid=186380 if regexm(mba, "rutgers")==1 
  replace mbaunitid=228723 if regexm(mba, "texas a&m")==1 
  replace mbaunitid=168148 if regexm(mba, "tufts")==1 
  replace mbaunitid=110635 if regexm(mba, "university of california")==1 
  replace mbaunitid=201885 if regexm(mba, "university of cincinnati")==1   
  replace mbaunitid=129020 if regexm(mba, "university of connecticut")==1 
  replace mbaunitid=141574 if regexm(mba, "university of hawai")==1 
  replace mbaunitid=145637 if regexm(mba, "university of illinois")==1 
  replace mbaunitid=170976 if regexm(mba, "university of michigan")==1 
  replace mbaunitid=174066 if regexm(mba, "university of minnesota")==1 
  replace mbaunitid=181464 if regexm(mba, "university of nebraska-lincoln")==1   
  replace mbaunitid=199120 if regexm(mba, "university of north carolina")==1 
  replace mbaunitid=152080 if regexm(mba, "university of notre dame")==1   
  replace mbaunitid=195030 if regexm(mba, "university of rochester")==1 
  replace mbaunitid=123961 if regexm(mba, "university of southern california")==1 
  replace mbaunitid=221759 if regexm(mba, "university of tennessee")==1 
  replace mbaunitid=228778 if regexm(mba, "university of texas")==1 
  replace mbaunitid=234076 if regexm(mba, "university of virginia")==1 
  replace mbaunitid=236948 if regexm(mba, "university of washington")==1  
  replace mbaunitid=240444 if regexm(mba, "university of wisconsin")==1  
  replace mbaunitid=126614 if regexm(mba, "university of colorado")==1
  
    replace mbaunitid=164465 if regexm(mba, "amherst")==1
  replace mbaunitid=189097 if regexm(mba, "barnard")==1
  replace mbaunitid=160977 if regexm(mba, "bates")==1
  replace mbaunitid=164924 if regexm(mba, "boston college")==1
  replace mbaunitid=161004 if regexm(mba, "bowdoin")==1
  replace mbaunitid=165015 if regexm(mba, "brandeis")==1
  replace mbaunitid=217156 if regexm(mba, "brown")==1
  replace mbaunitid=211273 if regexm(mba, "bryn mawr")==1
  replace mbaunitid=211291 if regexm(mba, "bucknell")==1
  replace mbaunitid=110404 if regexm(mba, "caltech")==1
  replace mbaunitid=173258 if regexm(mba, "carleton")==1
  replace mbaunitid=112260 if regexm(mba, "claremont mckenna")==1
  replace mbaunitid=161086 if regexm(mba, "colby")==1
  replace mbaunitid=190099 if regexm(mba, "colgate")==1
  replace mbaunitid=126678 if regexm(mba, "colorado")==1
  replace mbaunitid=190150 if regexm(mba, "columbia")==1
  replace mbaunitid=190415 if regexm(mba, "cornell")==1
  replace mbaunitid=182670 if regexm(mba, "dartmouth")==1
  replace mbaunitid=198385 if regexm(mba, "davidson")==1
  replace mbaunitid=198419 if regexm(mba, "duke")==1
  replace mbaunitid=139658 if regexm(mba, "emory")==1
  replace mbaunitid=131496 if regexm(mba, "georgetown")==1
  replace mbaunitid=153384 if regexm(mba, "grinnell")==1
  replace mbaunitid=191515 if regexm(mba, "hamilton")==1
  replace mbaunitid=166027 if regexm(mba, "harvard")==1
  replace mbaunitid=212911 if regexm(mba, "haverford")==1
  replace mbaunitid=162928 if regexm(mba, "johns hopkins")==1
  replace mbaunitid=203535 if regexm(mba, "kenyon")==1
  replace mbaunitid=213385 if regexm(mba, "lafayette")==1
  replace mbaunitid=173902 if regexm(mba, "macalester")==1
  replace mbaunitid=230959 if regexm(mba, "middlebury")==1
  replace mbaunitid=166683 if mba=="mit"
  replace mbaunitid=166939 if regexm(mba, "mount holyoke")==1
  replace mbaunitid=147767 if regexm(mba, "northwestern")==1
  replace mbaunitid=193900 if regexm(mba, "nyu")==1
  replace mbaunitid=204501 if regexm(mba, "oberlin")==1
  replace mbaunitid=121345 if regexm(mba, "pomona")==1
  replace mbaunitid=186131 if regexm(mba, "princeton")==1
  replace mbaunitid=227757 if regexm(mba, "rice")==1
  replace mbaunitid=167835 if regexm(mba, "smith")==1
  replace mbaunitid=243744 if regexm(mba, "stanford")==1
  replace mbaunitid=216287 if regexm(mba, "swarthmore")==1
  replace mbaunitid=130590 if regexm(mba, "trinity")==1
  replace mbaunitid=144050 if regexm(mba, "university of chicago")==1
  replace mbaunitid=215062 if regexm(mba, "university of pennsylvania")==1
  replace mbaunitid=221999 if regexm(mba, "vanderbilt")==1
  replace mbaunitid=197133 if regexm(mba, "vassar")==1
  replace mbaunitid=179867 if regexm(mba, "washington university")==1
  replace mbaunitid=168218 if regexm(mba, "wellesley")==1
  replace mbaunitid=130697 if regexm(mba, "wesleyan")==1
  replace mbaunitid=168342 if regexm(mba, "williams")==1
  replace mbaunitid=130794 if regexm(mba, "yale")==1
replace mbaunitid=188429 if mba=="adelphi university"
replace mbaunitid=197708 if mba=="albert einstein college of medicine"
replace mbaunitid=131159 if mba=="american university"
replace mbaunitid=100830 if mba=="auburn university"
replace mbaunitid=100830 if mba=="auburn university"
replace mbaunitid=164580 if mba=="babson college"
replace mbaunitid=164580 if mba=="babson college"
replace mbaunitid=190512 if mba=="baruch college"
replace mbaunitid=223232 if mba=="baylor university (jd)"
replace mbaunitid=238333 if mba=="beloit college"
replace mbaunitid=196079 if mba=="binghamton university"
replace mbaunitid=230038 if mba=="brigham young university"
replace mbaunitid=190549 if mba=="brooklyn college"
replace mbaunitid=110422 if mba=="california state polytechnical university"
replace mbaunitid=110583 if mba=="california state university, long beach"
replace mbaunitid=110592 if mba=="california state university, los angeles"
replace mbaunitid=169080 if mba=="calvin college"
replace mbaunitid=111948 if mba=="chapman university"
replace mbaunitid=181002 if mba=="creighton university"
replace mbaunitid=150400 if mba=="depauw university"
replace mbaunitid=212009 if mba=="dickinson college"
replace mbaunitid=177214 if mba=="drury university"
replace mbaunitid=169798 if mba=="eastern michigan university"
replace mbaunitid=433660 if mba=="florida gulf coast university"
replace mbaunitid=115755 if mba=="humboldt state university"
replace mbaunitid=190594 if mba=="hunter college"
replace mbaunitid=151290 if mba=="indian institute of technology"
replace mbaunitid=203368 if mba=="john carroll university"
replace mbaunitid=170532 if mba=="kalamazoo college"
replace mbaunitid=226231 if mba=="letourneau university"
replace mbaunitid=192448 if mba=="long island university"
replace mbaunitid=146719 if mba=="loyola university"
replace mbaunitid=237525 if mba=="marshall university"
replace mbaunitid=155511 if mba=="mcpherson college"
replace mbaunitid=204006 if mba=="miami university"
replace mbaunitid=220978 if mba=="middle tennessee state university"
replace mbaunitid=174358 if mba=="minnesota state university"
replace mbaunitid=199193 if mba=="north carolina state university"
replace mbaunitid=147703 if mba=="northern illinois university"
replace mbaunitid=171456 if mba=="northern michigan university"
replace mbaunitid=204635 if mba=="ohio northern university"
replace mbaunitid=121150 if mba=="pepperdine university"
replace mbaunitid=233277 if mba=="radford university"
replace mbaunitid=217493 if mba=="rhode island school of design"
replace mbaunitid=163851 if mba=="salisbury state university"
replace mbaunitid=122409 if mba=="san diego state university"
replace mbaunitid=122755 if mba=="san jose state university"
replace mbaunitid=122931 if mba=="santa clara university"
replace mbaunitid=228246 if mba=="southern methodist university"
replace mbaunitid=228343 if mba=="southwestern university"
replace mbaunitid=174792 if mba=="st. john's university"
replace mbaunitid=110662 if mba=="ucla"
replace mbaunitid=196097 if mba=="stony brook university"
replace mbaunitid=196413 if mba=="syracuse university"
replace mbaunitid=216339 if mba=="temple university"
replace mbaunitid=221838 if mba=="tennessee state university"
replace mbaunitid=221847 if mba=="tennessee technological university"
replace mbaunitid=229115 if mba=="texas tech university"
replace mbaunitid=160755 if mba=="tulane university"
replace mbaunitid=164155 if mba=="united states naval academy"
replace mbaunitid=104179 if mba=="university of arizona"
replace mbaunitid=106397 if mba=="university of arkansas"
replace mbaunitid=161873 if mba=="university of baltimore"
replace mbaunitid=106704 if mba=="university of central arkansas"
replace mbaunitid=169716 if mba=="university of detroit, mercy"
replace mbaunitid=135726 if mba=="university of miami"
replace mbaunitid=178396 if mba=="university of missouri"
replace mbaunitid=181215 if mba=="university of nebraska"
replace mbaunitid=159939 if mba=="university of new orleans"
replace mbaunitid=209551 if mba=="university of oregon"
replace mbaunitid=215293 if mba=="university of pittsburgh"
replace mbaunitid=120883 if mba=="university of the pacific"
replace mbaunitid=230764 if mba=="university of utah"
replace mbaunitid=110662 if mba=="universtiy of california, los angeles"
replace mbaunitid=216597 if mba=="villanova university"
replace mbaunitid=199847 if mba=="wake forest university"
replace mbaunitid=236939 if mba=="washington state university"
replace mbaunitid=172644 if mba=="wayne state university law school"
replace mbaunitid=157951 if mba=="western kentucky university"
replace mbaunitid=172699 if mba=="western michigan university"
replace mbaunitid=156125 if mba=="wichita state university"
replace mbaunitid=218973 if mba=="wofford college"

gen jdunitid=.
  replace jdunitid=166629 if regexm(jd, "university of massachusetts amherst")==1
  replace jdunitid=189097 if regexm(jd, "barnard")==1
  replace jdunitid=160977 if regexm(jd, "bates")==1
  replace jdunitid=164924 if regexm(jd, "boston college")==1
  replace jdunitid=161004 if regexm(jd, "bowdoin")==1
  replace jdunitid=165015 if regexm(jd, "brandeis")==1
  replace jdunitid=217156 if regexm(jd, "brown")==1
  replace jdunitid=211273 if regexm(jd, "bryn mawr")==1
  replace jdunitid=211291 if regexm(jd, "bucknell")==1
  replace jdunitid=110404 if regexm(jd, "caltech")==1
  replace jdunitid=173258 if regexm(jd, "carleton")==1
  replace jdunitid=112260 if regexm(jd, "claremont mckenna")==1
  replace jdunitid=161086 if regexm(jd, "colby")==1
  replace jdunitid=190099 if regexm(jd, "colgate")==1
  replace jdunitid=126818 if regexm(jd, "colorado state")==1
  replace jdunitid=190150 if regexm(jd, "columbia")==1
  replace jdunitid=190415 if regexm(jd, "cornell")==1
  replace jdunitid=182670 if regexm(jd, "dartmouth")==1
  replace jdunitid=198385 if regexm(jd, "davidson")==1
  replace jdunitid=198419 if regexm(jd, "duke")==1
  replace jdunitid=139658 if regexm(jd, "emory")==1
  replace jdunitid=131496 if regexm(jd, "georgetown")==1
  replace jdunitid=153384 if regexm(jd, "grinnell")==1
  replace jdunitid=191515 if regexm(jd, "hamilton")==1
  replace jdunitid=166027 if regexm(jd, "harvard university")==1
  replace jdunitid=212911 if regexm(jd, "haverford")==1
  replace jdunitid=162928 if regexm(jd, "johns hopkins")==1
  replace jdunitid=203535 if regexm(jd, "kenyon")==1
  replace jdunitid=173902 if regexm(jd, "macalester")==1
  replace jdunitid=230959 if regexm(jd, "middlebury")==1
  replace jdunitid=166683 if regexm(jd, "massachusetts institute of technology")==1
  replace jdunitid=166939 if regexm(jd, "mount holyoke")==1
  replace jdunitid=147767 if regexm(jd, "northwestern")==1
  replace jdunitid=193900 if regexm(jd, "new york university")==1
  replace jdunitid=204501 if regexm(jd, "oberlin")==1
  replace jdunitid=121345 if regexm(jd, "pomona")==1
  replace jdunitid=186131 if regexm(jd, "princeton")==1
  replace jdunitid=227757 if regexm(jd, "rice")==1
  replace jdunitid=167835 if regexm(jd, "smith")==1
  replace jdunitid=243744 if regexm(jd, "stanford")==1
  replace jdunitid=216287 if regexm(jd, "swarthmore")==1
  replace jdunitid=130590 if regexm(jd, "trinity")==1
  replace jdunitid=144050 if regexm(jd, "university of chicago")==1
  replace jdunitid=215062 if regexm(jd, "university of pennsylvania")==1
  replace jdunitid=221999 if regexm(jd, "vanderbilt")==1
  replace jdunitid=197133 if regexm(jd, "vassar")==1
  replace jdunitid=179867 if regexm(jd, "washington university")==1
  replace jdunitid=168218 if regexm(jd, "wellesley")==1
  replace jdunitid=130697 if regexm(jd, "wesleyan")==1
  replace jdunitid=168342 if regexm(jd, "williams")==1
  replace jdunitid=130794 if regexm(jd, "yale")==1

**NEW jdunitid CODING BY HYUNSU**
  replace jdunitid=243780 if regexm(jd, "purdue")==1
  replace jdunitid=102614 if regexm(jd, "alaska")==1
  replace jdunitid=104179 if regexm(jd, "arizona state")==1
  replace jdunitid=164988 if regexm(jd, "boston university")==1
  replace jdunitid=110404 if regexm(jd, "california institute of technology")==1
  replace jdunitid=211440 if regexm(jd, "carnegie mellon")==1
  replace jdunitid=201645 if regexm(jd, "case western reserve")==1
  replace jdunitid=232186 if regexm(jd, "george mason")==1
  replace jdunitid=139959 if regexm(jd, "georgia")==1
  replace jdunitid=151351 if regexm(jd, "indiana")==1  
  replace jdunitid=163286 if regexm(jd, "maryland")==1 
  replace jdunitid=166683 if regexm(jd, "massachusetts institute of technology")==1 
  replace jdunitid=171100 if regexm(jd, "michigan state")==1 
  replace jdunitid=193900 if regexm(jd, "new york")==1   
  replace jdunitid=167358 if regexm(jd, "northeastern")==1 
  replace jdunitid=204796 if regexm(jd, "ohio state")==1 
  replace jdunitid=209542 if regexm(jd, "oregon state")==1   
  replace jdunitid=214777 if regexm(jd, "pennsylvania state")==1 
  replace jdunitid=186380 if regexm(jd, "rutgers")==1 
  replace jdunitid=228723 if regexm(jd, "texas a&m")==1 
  replace jdunitid=168148 if regexm(jd, "tufts")==1 
  replace jdunitid=110635 if regexm(jd, "university of california")==1 
  replace jdunitid=201885 if regexm(jd, "university of cincinnati")==1   
  replace jdunitid=129020 if regexm(jd, "university of connecticut")==1 
  replace jdunitid=141574 if regexm(jd, "university of hawai")==1 
  replace jdunitid=145637 if regexm(jd, "university of illinois")==1 
  replace jdunitid=170976 if regexm(jd, "university of michigan")==1 
  replace jdunitid=174066 if regexm(jd, "university of minnesota")==1 
  replace jdunitid=181464 if regexm(jd, "university of nebraska-lincoln")==1   
  replace jdunitid=199120 if regexm(jd, "university of north carolina")==1 
  replace jdunitid=152080 if regexm(jd, "university of notre dame")==1   
  replace jdunitid=195030 if regexm(jd, "university of rochester")==1 
  replace jdunitid=123961 if regexm(jd, "university of southern california")==1 
  replace jdunitid=221759 if regexm(jd, "university of tennessee")==1 
  replace jdunitid=228778 if regexm(jd, "university of texas")==1 
  replace jdunitid=234076 if regexm(jd, "university of virginia")==1 
  replace jdunitid=236948 if regexm(jd, "university of washington")==1  
  replace jdunitid=240444 if regexm(jd, "university of wisconsin")==1  
  replace jdunitid=126614 if regexm(jd, "university of colorado")==1
  
    replace jdunitid=164465 if regexm(jd, "amherst")==1
  replace jdunitid=189097 if regexm(jd, "barnard")==1
  replace jdunitid=160977 if regexm(jd, "bates")==1
  replace jdunitid=164924 if regexm(jd, "boston college")==1
  replace jdunitid=161004 if regexm(jd, "bowdoin")==1
  replace jdunitid=165015 if regexm(jd, "brandeis")==1
  replace jdunitid=217156 if regexm(jd, "brown")==1
  replace jdunitid=211273 if regexm(jd, "bryn mawr")==1
  replace jdunitid=211291 if regexm(jd, "bucknell")==1
  replace jdunitid=110404 if regexm(jd, "caltech")==1
  replace jdunitid=173258 if regexm(jd, "carleton")==1
  replace jdunitid=112260 if regexm(jd, "claremont mckenna")==1
  replace jdunitid=161086 if regexm(jd, "colby")==1
  replace jdunitid=190099 if regexm(jd, "colgate")==1
  replace jdunitid=126678 if regexm(jd, "colorado")==1
  replace jdunitid=190150 if regexm(jd, "columbia")==1
  replace jdunitid=190415 if regexm(jd, "cornell")==1
  replace jdunitid=182670 if regexm(jd, "dartmouth")==1
  replace jdunitid=198385 if regexm(jd, "davidson")==1
  replace jdunitid=198419 if regexm(jd, "duke")==1
  replace jdunitid=139658 if regexm(jd, "emory")==1
  replace jdunitid=131496 if regexm(jd, "georgetown")==1
  replace jdunitid=153384 if regexm(jd, "grinnell")==1
  replace jdunitid=191515 if regexm(jd, "hamilton")==1
  replace jdunitid=166027 if regexm(jd, "harvard")==1
  replace jdunitid=212911 if regexm(jd, "haverford")==1
  replace jdunitid=162928 if regexm(jd, "johns hopkins")==1
  replace jdunitid=203535 if regexm(jd, "kenyon")==1
  replace jdunitid=213385 if regexm(jd, "lafayette")==1
  replace jdunitid=173902 if regexm(jd, "macalester")==1
  replace jdunitid=230959 if regexm(jd, "middlebury")==1
  replace jdunitid=166683 if jd=="mit"
  replace jdunitid=166939 if regexm(jd, "mount holyoke")==1
  replace jdunitid=147767 if regexm(jd, "northwestern")==1
  replace jdunitid=193900 if regexm(jd, "nyu")==1
  replace jdunitid=204501 if regexm(jd, "oberlin")==1
  replace jdunitid=121345 if regexm(jd, "pomona")==1
  replace jdunitid=186131 if regexm(jd, "princeton")==1
  replace jdunitid=227757 if regexm(jd, "rice")==1
  replace jdunitid=167835 if regexm(jd, "smith")==1
  replace jdunitid=243744 if regexm(jd, "stanford")==1
  replace jdunitid=216287 if regexm(jd, "swarthmore")==1
  replace jdunitid=130590 if regexm(jd, "trinity")==1
  replace jdunitid=144050 if regexm(jd, "university of chicago")==1
  replace jdunitid=215062 if regexm(jd, "university of pennsylvania")==1
  replace jdunitid=221999 if regexm(jd, "vanderbilt")==1
  replace jdunitid=197133 if regexm(jd, "vassar")==1
  replace jdunitid=179867 if regexm(jd, "washington university")==1
  replace jdunitid=168218 if regexm(jd, "wellesley")==1
  replace jdunitid=130697 if regexm(jd, "wesleyan")==1
  replace jdunitid=168342 if regexm(jd, "williams")==1
  replace jdunitid=130794 if regexm(jd, "yale")==1
replace jdunitid=188429 if jd=="adelphi university"
replace jdunitid=197708 if jd=="albert einstein college of medicine"
replace jdunitid=131159 if jd=="american university"
replace jdunitid=100830 if jd=="auburn university"
replace jdunitid=100830 if jd=="auburn university"
replace jdunitid=164580 if jd=="babson college"
replace jdunitid=164580 if jd=="babson college"
replace jdunitid=190512 if jd=="baruch college"
replace jdunitid=223232 if jd=="baylor university (jd)"
replace jdunitid=238333 if jd=="beloit college"
replace jdunitid=196079 if jd=="binghamton university"
replace jdunitid=230038 if jd=="brigham young university"
replace jdunitid=190549 if jd=="brooklyn college"
replace jdunitid=110422 if jd=="california state polytechnical university"
replace jdunitid=110583 if jd=="california state university, long beach"
replace jdunitid=110592 if jd=="california state university, los angeles"
replace jdunitid=169080 if jd=="calvin college"
replace jdunitid=111948 if jd=="chapman university"
replace jdunitid=181002 if jd=="creighton university"
replace jdunitid=150400 if jd=="depauw university"
replace jdunitid=212009 if jd=="dickinson college"
replace jdunitid=177214 if jd=="drury university"
replace jdunitid=169798 if jd=="eastern michigan university"
replace jdunitid=433660 if jd=="florida gulf coast university"
replace jdunitid=115755 if jd=="humboldt state university"
replace jdunitid=190594 if jd=="hunter college"
replace jdunitid=151290 if jd=="indian institute of technology"
replace jdunitid=203368 if jd=="john carroll university"
replace jdunitid=170532 if jd=="kalamazoo college"
replace jdunitid=226231 if jd=="letourneau university"
replace jdunitid=192448 if jd=="long island university"
replace jdunitid=146719 if jd=="loyola university"
replace jdunitid=237525 if jd=="marshall university"
replace jdunitid=155511 if jd=="mcpherson college"
replace jdunitid=204006 if jd=="miami university"
replace jdunitid=220978 if jd=="middle tennessee state university"
replace jdunitid=174358 if jd=="minnesota state university"
replace jdunitid=199193 if jd=="north carolina state university"
replace jdunitid=147703 if jd=="northern illinois university"
replace jdunitid=171456 if jd=="northern michigan university"
replace jdunitid=204635 if jd=="ohio northern university"
replace jdunitid=121150 if jd=="pepperdine university"
replace jdunitid=233277 if jd=="radford university"
replace jdunitid=217493 if jd=="rhode island school of design"
replace jdunitid=163851 if jd=="salisbury state university"
replace jdunitid=122409 if jd=="san diego state university"
replace jdunitid=122755 if jd=="san jose state university"
replace jdunitid=122931 if jd=="santa clara university"
replace jdunitid=228246 if jd=="southern methodist university"
replace jdunitid=228343 if jd=="southwestern university"
replace jdunitid=174792 if jd=="st. john's university"
replace jdunitid=110662 if jd=="ucla"
replace jdunitid=196097 if jd=="stony brook university"
replace jdunitid=196413 if jd=="syracuse university"
replace jdunitid=216339 if jd=="temple university"
replace jdunitid=221838 if jd=="tennessee state university"
replace jdunitid=221847 if jd=="tennessee technological university"
replace jdunitid=229115 if jd=="texas tech university"
replace jdunitid=160755 if jd=="tulane university"
replace jdunitid=164155 if jd=="united states naval academy"
replace jdunitid=104179 if jd=="university of arizona"
replace jdunitid=106397 if jd=="university of arkansas"
replace jdunitid=161873 if jd=="university of baltimore"
replace jdunitid=106704 if jd=="university of central arkansas"
replace jdunitid=169716 if jd=="university of detroit, mercy"
replace jdunitid=135726 if jd=="university of miami"
replace jdunitid=178396 if jd=="university of missouri"
replace jdunitid=181215 if jd=="university of nebraska"
replace jdunitid=159939 if jd=="university of new orleans"
replace jdunitid=209551 if jd=="university of oregon"
replace jdunitid=215293 if jd=="university of pittsburgh"
replace jdunitid=120883 if jd=="university of the pacific"
replace jdunitid=230764 if jd=="university of utah"
replace jdunitid=110662 if jd=="universtiy of california, los angeles"
replace jdunitid=216597 if jd=="villanova university"
replace jdunitid=199847 if jd=="wake forest university"
replace jdunitid=236939 if jd=="washington state university"
replace jdunitid=172644 if jd=="wayne state university law school"
replace jdunitid=157951 if jd=="western kentucky university"
replace jdunitid=172699 if jd=="western michigan university"
replace jdunitid=156125 if jd=="wichita state university"
replace jdunitid=218973 if jd=="wofford college"
}

// %%
rename boardunitid1 unitid

merge m:1 unitid year using d_school_level_elite_embed, nogen keep(1 3) ///
keepusing(schooltypenum)

gen boardtop30private=schooltypenum==3
gen boardtop30public=schooltypenum==2

rename schooltypenum boardschooltype
rename  unitid boardunitid1
// Out:
// (variable unitid was long, now double to accommodate using data's values)
// (variable year was int, now double to accommodate using data's values)
//
//     Result                      Number of obs
//     -----------------------------------------
//     Not matched                         1,081
//         from master                     1,081
//         from using                          0
//
//     Matched                               119
//     -----------------------------------------

// %%
rename collegeunitid unitid

merge m:1 unitid year using d_school_level_elite_embed, nogen keep(1 3) ///
keepusing(schooltypenum)

rename schooltypenum collegeschooltype
rename unitid collegeunitid 

rename mbaunitid unitid

merge m:1 unitid year using d_school_level_elite_embed, nogen keep(1 3) ///
keepusing(schooltypenum)

rename schooltypenum mbaschooltype
rename unitid mbaunitid

rename jdunitid unitid

merge m:1 unitid year using d_school_level_elite_embed, nogen keep(1 3) ///
keepusing(schooltypenum)

rename schooltypenum jdschooltype
rename unitid jdunitid

replace collegeschooltype=4 if college=="" | college=="highschool"
replace collegeschooltype=1 if collegeschooltype==.

replace mbaschooltype=4 if mba==""
replace mbaschooltype=1 if mbaschooltype==.

replace jdschooltype=4 if jd==""
replace jdschooltype=1 if jdschooltype==.

merge m:1 year using cpi_scalar2017, keep(1 3)
// Out:
// (variable unitid was float, now double to accommodate using data's values)
// (label _merge already defined)
// (label schooltype already defined)
//
//     Result                      Number of obs
//     -----------------------------------------
//     Not matched                           832
//         from master                       832
//         from using                          0
//
//     Matched                               368
//     -----------------------------------------
//
//
//
//
// (variable unitid was float, now double to accommodate using data's values)
// (label _merge already defined)
// (label schooltype already defined)
//
//     Result                      Number of obs
//     -----------------------------------------
//     Not matched                         1,077
//         from master                     1,077
//         from using                          0
//
//     Matched                               123
// ...

// %%
qui {
    gen inherited=0
replace inherited=1 if selfmade=="self-made"
replace inherited=1 if regexm(origin, "inherit")==1
replace inherited=1 if regexm(origindetail, "inherit")==1

replace worth=.275 if worth==.
replace worth=worth/1000 if year==1989 | worthunit=="million,"

replace worth=worth / cpi_scalar_2017

gen pe=0
replace pe=1 if financedetail=="private equity" | financedetail=="venture capital"

gen hedge=0
replace hedge=1 if financedetail=="hedge funds"

gen otherfin=0
replace otherfin=1 if financedetail!="non-financial" & pe!=1 & hedge!=1 & financedetail!=" non-financial"

gen financial=0
replace financial=1 if financedetail!="non-financial" & financedetail!=" non-financial"
replace technology=0 if financial==1
replace technology=0 if technology!=1

egen id=group(firstname lastname suffix), missing
quietly egen finance=rowtotal(pe hedge otherfin)
quietly egen pehedge=rowtotal(pe hedge)
replace id=895 if id==712 & middlen=="alfred"
replace id=896 if id==311 & middlen==""
    
}

// %%
save d_forbes400_alum_board_1989_2003_2017, replace
// Out:
// file d_forbes400_alum_board_1989_2003_2017.dta saved
